# %%
import sys
import os
sys.path.append(os.path.expanduser('~') + '/igm_emulator/igm_emulator/hmc/test')
from chi_debug import *
# %matplotlib notebook
# Out:
# <KeysViewHDF5 ['meanX', 'meanY', 'stdX', 'stdY', 'test_data', 'train_data', 'vali_data']>
# <KeysViewHDF5 ['R2', 'residuals_results', 'test_loss', 'train_loss', 'vali_loss']>
# chi2 per dof emulator: 0.11487931781274179,chi2 per dof molly: 0.0
# <img src="data:image/png;base64,..." width="1000">
